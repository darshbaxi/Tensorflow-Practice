# %% [markdown]
# <a href="https://colab.research.google.com/github/darshbaxi/Tensorflow-Practice/blob/main/Drawing_shapes_and_text_on_Images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
blank=np.zeros((500,500,3))
cv2_imshow(blank)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7FC387EAF1F0>
# -1

# %%
blank[200:300,300:400]=0,255,0
cv2_imshow(blank)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7FC387F34F40>
# -1

# %%
##DRAWING RECTANGLE
cv2.rectangle(blank,(150,150),(450,450),(0,250,0),thickness=2)
cv2_imshow(blank)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F494CEB2C80>

# %%
cv2.rectangle(blank,(150,150),(450,450),(0,250,0),thickness=-1)
cv2_imshow(blank)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F494CEB2DD0>

# %%
blank[200:300,300:400]=0,0,255
cv2_imshow(blank)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F4924E77FA0>

# %%
## DRAWING CIRCLE

blank_space=np.zeros((500,500,3))
cv2.circle(blank_space,(250,250),5,(255,0,0),thickness=2)
cv2.circle(blank_space,(250,250),50,(255,0,0),thickness=2)
cv2.circle(blank_space,(150,150),100,(255,0,0),thickness=-1)
cv2_imshow(blank_space)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F490F231A20>

# %%
## DRAWING LINE

blankspace=np.zeros((500,500,3))
cv2.line(blankspace,(100,100),(400,400),(0,0,255),thickness=1)
cv2.line(blankspace,(100,100),(100,400),(0,0,255),thickness=1)
cv2.line(blankspace,(400,100),(400,400),(0,0,255),thickness=1)
cv2.line(blankspace,(100,100),(400,100),(0,0,255),thickness=2)
cv2.line(blankspace,(100,400),(400,400),(0,0,255),thickness=10)
cv2_imshow(blankspace)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F490F233430>

# %%
## DRAWING TEXT

blanks=np.zeros((500,500,3))
cv2.putText(blanks,'OPEN_CV',(250,250),cv2.FONT_ITALIC,1.0,(255,255,255),2)
cv2_imshow(blanks)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F490F233910>

# %%
blankss=np.zeros((500,500,3))
cv2.putText(blankss,'DARSH',(150,250),cv2.FONT_ITALIC,1.0,(255,255,255),2)
cv2_imshow(blankss)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7FDF4D34A110>

# %%
canva=np.zeros((500,500,3))
## cv2.ellopse(name,(startcordi),(breath,lenght),angle,start_angle,end_angle,color,thickness)
cv2.ellipse(canva,(100,100),(10,50),60,0,360,125,2)
cv2_imshow(canva)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7FDF19385BD0>
